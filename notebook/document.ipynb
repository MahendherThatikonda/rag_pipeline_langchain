# %% [markdown]
# ### Data Ingestion

# %%
### document datastructure

from langchain_core.documents  import Document

# %%
doc =Document(
    page_content="This is the main text content i'm using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":"1",
        "author":"Mahendher",
        "Date_created": "2025-12-01"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': '1', 'author': 'Mahendher', 'Date_created': '2025-12-01'}, page_content="This is the main text content i'm using to create RAG")

# %%
## create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""python programming Introduction

    Python is a popular, general-purpose programming language known for its simple, English-like syntax and emphasis on code readability, making it an excellent choice for beginners. It was created by Guido van Rossum and first released in 1991. 
Key Features and Concepts
Beginner-Friendly: Python's design prioritizes ease of use and an intuitive coding style, which helps new programmers learn quickly.
Interpreted Language: Python code is executed line by line at runtime by an interpreter, which facilitates rapid prototyping and easier debugging, as you don't need to compile the entire program first.
Dynamically Typed: You do not need to explicitly declare the data type of a variable (e.g., as integer, string, etc.) when you create it; the interpreter determines the type automatically.
Versatile: Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming, and has a vast standard library and third-party packages that extend its functionality.
Platform Independent: Code can be written once and run on various operating systems like Windows, macOS, and Linux without needing modifications. """,

"../data/text_files/machinelearning_intro.txt":"""Machine Learning Introduction

Machine learning is a subfield of AI where computers learn to identify patterns and make predictions from data, rather than being explicitly programmed for every task. It involves feeding algorithms large amounts of data so they can build models and learn to perform tasks like image recognition, language translation, and fraud detection. The core idea is to enable systems to improve their performance and accuracy over time as they are exposed to more data. 
How it works
Data-driven learning: Instead of following pre-written rules, a machine learning model learns the rules itself by analyzing patterns in the data it is given.
Training: Algorithms are "trained" on a dataset to learn the underlying patterns. This is like showing a student many examples so they can learn to solve new problems.
Prediction: After training, the model can use the patterns it learned to make accurate predictions or decisions on new, unseen data.
Continuous improvement: If the output is incorrect, the model can be fed this feedback to improve its accuracy over time.  """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
         f.write(content)

print("Sample Text Files Created")
# Out:
# Sample Text Files Created

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader  # ✅ new

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document  = loader.load()

print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="python programming Introduction\n\n    Python is a popular, general-purpose programming language known for its simple, English-like syntax and emphasis on code readability, making it an excellent choice for beginners. It was created by Guido van Rossum and first released in 1991. \nKey Features and Concepts\nBeginner-Friendly: Python's design prioritizes ease of use and an intuitive coding style, which helps new programmers learn quickly.\nInterpreted Language: Python code is executed line by line at runtime by an interpreter, which facilitates rapid prototyping and easier debugging, as you don't need to compile the entire program first.\nDynamically Typed: You do not need to explicitly declare the data type of a variable (e.g., as integer, string, etc.) when you create it; the interpreter determines the type automatically.\nVersatile: Python supports multiple programming paradigms, including procedur
# ...

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader, TextLoader

#load all the text files from directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)


documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machinelearning_intro.txt'}, page_content='Machine Learning Introduction\n\nMachine learning is a subfield of AI where computers learn to identify patterns and make predictions from data, rather than being explicitly programmed for every task. It involves feeding algorithms large amounts of data so they can build models and learn to perform tasks like image recognition, language translation, and fraud detection. The core idea is to enable systems to improve their performance and accuracy over time as they are exposed to more data. \nHow it works\nData-driven learning: Instead of following pre-written rules, a machine learning model learns the rules itself by analyzing patterns in the data it is given.\nTraining: Algorithms are "trained" on a dataset to learn the underlying patterns. This is like showing a student many examples so they can learn to solve new problems.\nPrediction: After training, the model can use the patterns it le
# ...
